# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Keshav\Downloads\eq2015.csv")

# %%
df.head()
# Out:
#     building_id  district_id  vdcmun_id  ward_id  count_floors_pre_eq  \
# 0  120101000011           12       1207   120703                    1
# 1  120101000021           12       1207   120703                    1
# 2  120101000031           12       1207   120703                    1
# 3  120101000041           12       1207   120703                    1
# 4  120101000051           12       1207   120703                    1
#
#    count_floors_post_eq  age_building  plinth_area_sq_ft  height_ft_pre_eq  \
# 0                     1             9                288                 9
# 1                     1            15                364                 9
# 2                     1            20                384                 9
# 3                     1            20                312                 9
# 4                     1            30                308                 9
#
#    height_ft_post_eq  ... foundation_type                 roof_type  \
# ...

# %%
df.tail()
# Out:
#          building_id  district_id  vdcmun_id  ward_id  count_floors_pre_eq  \
# 762101  366709001241           36       3603   360302                    2
# 762102  366709001251           36       3603   360302                    2
# 762103  366709001261           36       3603   360302                    2
# 762104  366709001271           36       3603   360302                    2
# 762105  366709001281           36       3603   360302                    2
#
#         count_floors_post_eq  age_building  plinth_area_sq_ft  \
# 762101                     0            60                165
# 762102                     0            35                342
# 762103                     0            35                342
# 762104                     0            19                306
# 762105                     0            12                840
#
#         height_ft_pre_eq  height_ft_post_eq  ...         foundation_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762106 entries, 0 to 762105
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   building_id                  762106 non-null  int64
#  1   district_id                  762106 non-null  int64
#  2   vdcmun_id                    762106 non-null  int64
#  3   ward_id                      762106 non-null  int64
#  4   count_floors_pre_eq          762106 non-null  int64
#  5   count_floors_post_eq         762106 non-null  int64
#  6   age_building                 762106 non-null  int64
#  7   plinth_area_sq_ft            762106 non-null  int64
#  8   height_ft_pre_eq             762106 non-null  int64
#  9   height_ft_post_eq            762106 non-null  int64
#  10  land_surface_condition       762106 non-null  object
#  11  foundation_type              762106 non-null  object
# ...

# %%
df.describe()
# Out:
#         building_id    district_id      vdcmun_id        ward_id  \
# count  7.621060e+05  762106.000000  762106.000000  762106.000000
# mean   2.607514e+11      25.767835    2582.688357  258274.277335
# std    5.801855e+10       5.807555     581.172767   58117.348412
# min    1.201010e+11      12.000000    1201.000000  120101.000000
# 25%    2.219090e+11      22.000000    2204.000000  220402.000000
# 50%    2.463020e+11      24.000000    2410.000000  241004.000000
# 75%    3.036080e+11      30.000000    3010.000000  301006.000000
# max    3.667090e+11      36.000000    3611.000000  361108.000000
#
#        count_floors_pre_eq  count_floors_post_eq   age_building  \
# count        762106.000000         762106.000000  762106.000000
# mean              2.087783              1.252058      24.326405
# std               0.655101              1.063275      65.043704
# min               1.000000              0.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# building_id                     0
# district_id                     0
# vdcmun_id                       0
# ward_id                         0
# count_floors_pre_eq             0
# count_floors_post_eq            0
# age_building                    0
# plinth_area_sq_ft               0
# height_ft_pre_eq                0
# height_ft_post_eq               0
# land_surface_condition          0
# foundation_type                 0
# roof_type                       0
# ground_floor_type               0
# other_floor_type                0
# position                        1
# plan_configuration              1
# condition_post_eq               0
# damage_grade                   12
# technical_solution_proposed    12
# superstructure                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 762101    False
# 762102    False
# 762103    False
# 762104    False
# 762105    False
# Length: 762094, dtype: bool

# %%
plt.figure(figsize=(10, 6))
df['damage_grade'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Univariate Analysis: Damage Grade Distribution')
plt.xlabel('Damage Grade')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['damage_grade'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange', 'lightgreen'])
plt.title('Univariate Analysis: Damage Grade Distribution')
plt.ylabel('')  # Remove y-axis label for better visualization
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='damage_grade', hue='condition_post_eq', palette='viridis')
plt.title('Bivariate Analysis: Damage Grade vs Condition Post Earthquake')
plt.xlabel('Damage Grade')
plt.ylabel('Count')
plt.legend(title='Condition Post EQ', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='age_building', y='plinth_area_sq_ft', hue='damage_grade', palette='viridis')
plt.title('Bivariate Analysis: Age of Building vs Plinth Area')
plt.xlabel('Age of Building')
plt.ylabel('Plinth Area (sq ft)')
plt.legend(title='Damage Grade')
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 762094 entries, 0 to 762105
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   building_id                  762094 non-null  int64
#  1   district_id                  762094 non-null  int64
#  2   vdcmun_id                    762094 non-null  int64
#  3   ward_id                      762094 non-null  int64
#  4   count_floors_pre_eq          762094 non-null  int64
#  5   count_floors_post_eq         762094 non-null  int64
#  6   age_building                 762094 non-null  int64
#  7   plinth_area_sq_ft            762094 non-null  int64
#  8   height_ft_pre_eq             762094 non-null  int64
#  9   height_ft_post_eq            762094 non-null  int64
#  10  land_surface_condition       762094 non-null  object
#  11  foundation_type              762094 non-null  object
#  12  roof_type                    762094 non-null  object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Convert all categorical columns to numerical
categorical_columns = df.select_dtypes(include=['object']).columns
for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

df.head()
# Out:
#     building_id  district_id  vdcmun_id  ward_id  count_floors_pre_eq  \
# 0  120101000011           12       1207   120703                    1
# 1  120101000021           12       1207   120703                    1
# 2  120101000031           12       1207   120703                    1
# 3  120101000041           12       1207   120703                    1
# 4  120101000051           12       1207   120703                    1
#
#    count_floors_post_eq  age_building  plinth_area_sq_ft  height_ft_pre_eq  \
# 0                     1             9                288                 9
# 1                     1            15                364                 9
# 2                     1            20                384                 9
# 3                     1            20                312                 9
# 4                     1            30                308                 9
#
#    height_ft_post_eq  ...  foundation_type  roof_type  ground_floor_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 762094 entries, 0 to 762105
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   building_id                  762094 non-null  int64
#  1   district_id                  762094 non-null  int64
#  2   vdcmun_id                    762094 non-null  int64
#  3   ward_id                      762094 non-null  int64
#  4   count_floors_pre_eq          762094 non-null  int64
#  5   count_floors_post_eq         762094 non-null  int64
#  6   age_building                 762094 non-null  int64
#  7   plinth_area_sq_ft            762094 non-null  int64
#  8   height_ft_pre_eq             762094 non-null  int64
#  9   height_ft_post_eq            762094 non-null  int64
#  10  land_surface_condition       762094 non-null  int32
#  11  foundation_type              762094 non-null  int32
#  12  roof_type                    762094 non-null  int32
# ...

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
X=df.iloc[:,[2,3,4,5,8]]
y=df[['superstructure']]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred1=model.predict(X)

# %%
df['Prediction']=y_pred1

# %%
df
# Out:
#          building_id  district_id  vdcmun_id  ward_id  count_floors_pre_eq  \
# 0       120101000011           12       1207   120703                    1
# 1       120101000021           12       1207   120703                    1
# 2       120101000031           12       1207   120703                    1
# 3       120101000041           12       1207   120703                    1
# 4       120101000051           12       1207   120703                    1
# ...              ...          ...        ...      ...                  ...
# 762101  366709001241           36       3603   360302                    2
# 762102  366709001251           36       3603   360302                    2
# 762103  366709001261           36       3603   360302                    2
# 762104  366709001271           36       3603   360302                    2
# 762105  366709001281           36       3603   360302                    2
#
#         count_floors_post_eq  age_building  plinth_area_sq_ft  \
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)

print('mae',mae)
print('mse',mse)
print('rmse',rmse)
print('r2',r2)
# Out:
# mae 0.8942436062916367
# mse 3.3191893986892604
# rmse 1.8218642646172245
# r2 0.005888962993642832
